# %% [markdown]
# <a href="https://colab.research.google.com/github/rogergerberquirino93502/Python-para-Data-Science/blob/main/AluraLatam_Roger.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Alura Inicios

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title(" Visualization")
plt.show()

# %%
print ("Hello")
# Out:
# Hello

# %%
nombre = 'Roger'

# %%
nombre
# Out:
# 'Roger'

# %%
'My names Roger'
# Out:
# 'My names Roger'

# %%
print('Hi')
# Out:
# Hi

# %% [markdown]
# #Funciones, Condicionales, Parametros, Conversion de tipos

# %%
def saludar():
  nombre = input('ingresar nombre ')
  print(f'Hola {nombre} , Bienvenido!!!')

# %%
saludar()
# Out:
# ingresar nombreRoger
# Hola Roger , Bienvenido!!!

# %%
saludar
# Out:
# <function __main__.saludar()>

# %%
saludar()
# Out:
# ingresar nombreRoger
# Hola Roger , Bienvenido!!!

# %%
saludar()
# Out:
# ingresar nombre Gerber
# Hola Gerber , Bienvenido!!!

# %%
def nombre_completo():
  primer_nombre = input('Cual es su primer nombre')
  apellido = input('Cual es su apellido')
  nombre_completo = primer_nombre + ' ' + apellido
  print(nombre_completo)
nombre_completo()
# Out:
# Cual es su primer nombreRoger
# Cual es su apellidoGerber
# Roger Gerber

# %%
nombre = "Andrea"

# %%
def saludar_con_parametros(nombre):
  print(f'Hola {nombre} sea bienvenida!!!')

# %%
saludar_con_parametros(nombre)
# Out:
# Hola Andrea sea bienvenida!!!

# %%
edad = 5

def verificar_si_puede_conducir(edad):
  if edad >= 18:
    print("Tiene edad suficiente para conducir")
  else:
    print("Usted No tiene edad suficiente para conducir")

verificar_si_puede_conducir(edad)
# Out:
# Usted No tiene edad suficiente para conducir

# %%
def clasificar_nps(nota):
  if nota <= 6:
    print('El alumno es considerado Detractor')
  else:
    if nota <= 8:
      print('El alumno es considerado Neutro')
    else:
      print('El alumno es considerado Promotor')

clasificar_nps(7)
# Out:
# El alumno es considerado Neutro

# %%
def verificar_si_puede_conducir_si_parametro():
  edad = input("Digite su edad: ")
  edad = int(edad)
  if edad >= 18:
    print("Usted tiene edad suficiente")
  else:
    print("No tiene edad")

verificar_si_puede_conducir_si_parametro()
# Out:
# Digite su edad: 25
# Usted tiene edad suficiente

# %% [markdown]
# #Listas en Python y bucles

# %%
edades = [18, 15, 20, 25]
def verificar_si_puede_conducir(edad):
  for edad in edades:
    if edad >=18:
      print("Puede conducir")
    else:
      print("No tiene edad")

verificar_si_puede_conducir(edades)
# Out:
# Puede conducir
# No tiene edad
# Puede conducir
# Puede conducir

# %% [markdown]
# #Booleano

# %%
persona = ['Juana', 25, 'Perez', 525]
for elemento in persona:
  print(f'El elemento {elemento} de la lista es del tipo', type(elemento))
# Out:
# El elemento Juana de la lista es del tipo <class 'str'>
# El elemento 25 de la lista es del tipo <class 'int'>
# El elemento Perez de la lista es del tipo <class 'str'>
# El elemento 525 de la lista es del tipo <class 'int'>

# %% [markdown]
# #Importando una biblioteca

# %%
from random import randrange, seed

# %%
randrange(0,11)
# Out:
# 0

# %%
notas_matematicas = []

# %%
notas_matematicas.append(randrange(0,11))

# %%
notas_matematicas
# Out:
# [9]

# %%
notas_matematicas = []
seed(8)
for notas in range(6):
  notas_matematicas.append(randrange(0,11))

# %%
notas_matematicas
# Out:
# [3, 5, 6, 2, 3, 0]

# %%
len(notas_matematicas)
# Out:
# 6

# %% [markdown]
# #Importando Biblioteca Matplotlib para graficos

# %%
import matplotlib.pyplot as plt

# %%
list(range(1,7))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x = list(range(1,7))
y= notas_matematicas

plt.plot(x,y, marker='o')
plt.plot(x,y)
plt.title('Grafico de las notas de Matemáticas')
plt.xlabel('Pruebas')
plt.ylabel('Notas')
plt.show()

# %% [markdown]
# #Analizando gráficamente el desempeño escolar

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

notas_matematica = ['Matemática',8,7,6,6,7,7,8,10]
notas_lenguaje = ['Lenguaje',9,9,9,8,5,6,8,5]
notas_geografia = ['Geografía',10,10,6,7,7,7,8,7]

notas = [notas_matematica, notas_lenguaje, notas_geografia]

# %%
for nota in notas:
 x = list(range(1, 9))
 y = nota[1:]
 plt.plot(x, y, marker='o')
 plt.xlabel('Exámenes')
 plt.ylabel('Notas')
 plt.title(nota[0])
 plt.show()
